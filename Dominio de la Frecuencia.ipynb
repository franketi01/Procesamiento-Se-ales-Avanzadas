# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 300  # Número de puntos o muestras
tiempo = np.linspace(1, 300, N)  # Vector de tiempo de 1 a 300

# %%
ciclos = 1
amplitud = 1

# Calcular seno para ciclos=1
seno1 = amplitud * np.sin(ciclos * 2 * np.pi * tiempo / N)

# Graficar para ciclos=1
plt.plot(tiempo, seno1, label='ciclos=1')

# %%
ciclos = 2
amplitud = 1
seno2 = amplitud * np.sin(ciclos * 2 * np.pi * tiempo / N)

# Graficar para ciclos=2
plt.plot(tiempo, seno2, label='ciclos=2')

# %%
# Calcular seno para ciclos=10
ciclos = 10
amplitud = 2
seno10 = amplitud * np.sin(ciclos * 2 * np.pi * tiempo / N)

# Graficar para ciclos=10
plt.plot(tiempo, seno10, label='ciclos=10')

# Añadir leyenda y etiquetas de ejes
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Ondas sinusoidales con diferentes ciclos y amplitudes')

# Mostrar el gráfico
plt.show()

# %%
ciclos = 20
amplitud = 0.5

# Calcular seno para ciclos=20
seno20 = amplitud * np.sin(ciclos * 2 * np.pi * tiempo / N)

# Graficar para ciclos=20
plt.plot(tiempo, seno20, label='ciclos=20')

# Calcular nivel DC
niveldc = np.ones(N)

# Graficar nivel DC
plt.plot(tiempo, niveldc, label='nivel DC')

# Calcular la suma de todas las ondas
seno121020dc = seno1 + seno2 + seno10 + seno20 + niveldc

# Graficar la suma de todas las ondas
plt.plot(tiempo, seno121020dc, label='suma de todas las ondas')

# Añadir leyenda y etiquetas de ejes
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Ondas sinusoidales con diferentes ciclos, amplitudes y nivel DC')

# Mostrar el gráfico
plt.show()

# %%
fft_seno1 = np.fft.fft(seno1)

# Calcular el módulo de la FFT y graficar
plt.plot(np.abs(fft_seno1), label='FFT de seno1')
plt.xlabel('Frecuencia')
plt.ylabel('Magnitud')
plt.title('Magnitud de la FFT de seno1')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calcular la FFT de seno2
fft_seno2 = np.fft.fft(seno2)

# Graficar la magnitud de la FFT de seno2
plt.plot(np.abs(fft_seno2), label='FFT de seno2')
plt.xlabel('Frecuencia')
plt.ylabel('Magnitud')
plt.title('Magnitud de la FFT de seno2')
plt.show()

# Calcular la FFT de seno10
fft_seno10 = np.fft.fft(seno10)

# Graficar la magnitud de la FFT de seno10
plt.plot(np.abs(fft_seno10), label='FFT de seno10')
plt.xlabel('Frecuencia')
plt.ylabel('Magnitud')
plt.title('Magnitud de la FFT de seno10')
plt.show()

# Calcular la FFT de seno20
fft_seno20 = np.fft.fft(seno20)

# Graficar la magnitud de la FFT de seno20
plt.plot(np.abs(fft_seno20), label='FFT de seno20')
plt.xlabel('Frecuencia')
plt.ylabel('Magnitud')
plt.title('Magnitud de la FFT de seno20')
plt.show()

# Calcular la FFT de niveldc
fft_niveldc = np.fft.fft(niveldc)

# Graficar la magnitud de la FFT de niveldc
plt.plot(np.abs(fft_niveldc), label='FFT de niveldc')
plt.xlabel('Frecuencia')
plt.ylabel('Magnitud')
plt.title('Magnitud de la FFT de niveldc')
plt.show()

# Calcular la FFT de seno121020dc
fft_seno121020dc = np.fft.fft(seno121020dc)

# Graficar la magnitud de la FFT de seno121020dc
plt.plot(np.abs(fft_seno121020dc), label='FFT de seno121020dc')
plt.xlabel('Frecuencia')
plt.ylabel('Magnitud')
plt.title('Magnitud de la FFT de seno121020dc')
plt.show()
